# %% [markdown]
# # Importing Libraries

# %%
pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.9.0-py2.py3-none-any.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.9.0

# %%
#importing necessary libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import emoji
import string
import nltk
from sklearn.preprocessing import LabelEncoder
#import pandas_profiling as pp

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from PIL import Image
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.tree import export_graphviz
import pickle

# %% [markdown]
# **Getting the data

# %%
data=pd.read_csv('/content/cyberbullying_tweets.csv')

# %% [markdown]
# # REVIEW OF THE DATA SET

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47692 entries, 0 to 47691
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_text          47692 non-null  object
#  1   cyberbullying_type  47692 non-null  object
# dtypes: object(2)
# memory usage: 745.3+ KB

# %%
data.head(10)
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# 5  @Raja5aab @Quickieleaks Yes, the test of god i...  not_cyberbullying
# 6  Itu sekolah ya bukan tempat bully! Ga jauh kay...  not_cyberbullying
# 7  Karma. I hope it bites Kat on the butt. She is...  not_cyberbullying
# 8       @stockputout everything but mostly my priest  not_cyberbullying
# 9  Rebecca Black Drops Out of School Due to Bully...  not_cyberbullying

# %%
data.sample(20)
# Out:
#                                               tweet_text   cyberbullying_type
# 34019  Oh there was. I was also the girl everyone fea...                  age
# 11678  I don't think rape jokes are funny, I don't th...               gender
# 31129                      @jsigj http://t.co/BXygHtfPk6  other_cyberbullying
# 5919   #YesAllWomen feel a combination of pride and r...    not_cyberbullying
# 44780  @Darknightt5150 @YouTube Fuck you stupid ass n...            ethnicity
# 45752  Marguerite came to understand what being and b...            ethnicity
# 34959  there has to be some correlation between girls...                  age
# 42971  Lmmfao RT @bobBOBBSbobby: RT @PainBueller: Tur...            ethnicity
# 10381  @jacklke yeah the show is horrible horrible co...               gender
# 15185  RT @Marshall_SS: Call me sexist but if a song ...               gender
# 21157  No she’s not. But she is a complete idiot &amp...             religion
# 34823  This girl I went to high school with put under...                  age
# 19765  Tibet, Hong Kong, and Muslims all say hello yo...             religion
# 44797  Lauren said you are dumb as fuck bitch ass nigger            ethnicity
# 15892  Because people yell "stan Loona" to rape victi...               gender
# 10510  As a whole, for the MOST part, people don’t li...               gender
# 40091  This person in office didn’t make anything wor...            ethnicity
# 2534          @cxarli nope. I had to manually block her.    not_cyberbullying
# 6711   [ad voiceover] The episode to break all record...    not_cyberbullying
# 10181  Lucky enough not to be bombarded with comments...               gender

# %% [markdown]
# ## Checking for missing values in the data set

# %%
data.isnull().sum()
# Out:
# tweet_text            0
# cyberbullying_type    0
# dtype: int64

# %% [markdown]
# ### No null values found

# %%
#Shape of the data set or dimersions of the data set
print('The number of rows present: ',data.shape[0])
print('The number of columns present: ',data.shape[1])
# Out:
# The number of rows present:  47692
# The number of columns present:  2

# %%
#Columns/ attributes present in the data set
print('The different columns present in the data set is: ', data.columns)
# Out:
# The different columns present in the data set is:  Index(['tweet_text', 'cyberbullying_type'], dtype='object')

# %%
#Looking for different types of data present in the cyber bullying columns
data['cyberbullying_type'].unique()
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)

# %% [markdown]
# ### We can see that there are six distinct types of cyber bullying present in the columns. Let us look the count of different types of cyber bullying present.

# %%
#Count of different types of tweets in the data set
data['cyberbullying_type'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: cyberbullying_type, dtype: int64

# %% [markdown]
# #### It can be seen that there are almost equal number of distribution of different types of cyberbulling tweets in the data set.

# %% [markdown]
# # We will be renaming the columns for better understanding

# %%
data=data.rename(columns={'tweet_text':'Text', 'cyberbullying_type':'Sentiment'})

# %%
data.head()
# Out:
#                                                 Text          Sentiment
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# ##  In this part we are going to encode each type of cyber bullying type into a number ranging from 1 - 6

# %%
data['Sentiment'].value_counts()
# Out:
# religion               7998
# age                    7992
# gender                 7973
# ethnicity              7961
# not_cyberbullying      7945
# other_cyberbullying    7823
# Name: Sentiment, dtype: int64

# %%
# profile = pp.ProfileReport(data)
# profile
# #profile.to_file('report.html')

# %% [markdown]
# ## The encoding will be done as follows:
# #### 1.religion                          1
# #### 2.age                                 2
# #### 3.gender                           3
# #### 4.ethnicity                        4
# #### 5.not_cyberbullying        5
# #### 6.other_cyberbullying    6

# %%
labelencoder=LabelEncoder()

#data.drop('Encoded_Sentiment',inplace=True, axis=1)


data['Sentiment_encoded']=labelencoder.fit_transform(data['Sentiment'])
data.sample(15)
# Out:
#                                                     Text            Sentiment  \
# 37570  haha i got a girl pregnant in high school so i...                  age
# 32818  The same men who bullied girls in high school ...                  age
# 33552  time to test it on your high school bullies/en...                  age
# 37548  I wonder how many of my bullies from high scho...                  age
# 6119         @georgarosex what colour milk do you drink?    not_cyberbullying
# 45448  @DSmithRB_04 @rid3forum you just look like eve...            ethnicity
# 18542  the Quran does not condone murder. only in sel...             religion
# 25129                 #GOPBloodMoney #trumpleaks #truâ¦  other_cyberbullying
# 35964  All the girls that bullied me in middle school...                  age
# 6698                        #thin http://t.co/Edyxcfk0Jm    not_cyberbullying
# 4083   @UnoriginalJohn @girlziplocked @ameliagreenhal...    not_cyberbullying
# 20322  Funny how anyone who disagrees with you is "fa...             religion
# 5671     @sschinke @teh_maxh what are you talking about?    not_cyberbullying
# 43805  “@madddierusssell: @ellsbelllls fuck off nigge...            ethnicity
# 47318  WE CLAPPING for COUGH SYRUP DRINKERS??? FUCK D...            ethnicity
#
#        Sentiment_encoded
# 37570                  0
# 32818                  0
# 33552                  0
# 37548                  0
# 6119                   3
# 45448                  1
# 18542                  5
# 25129                  4
# 35964                  0
# 6698                   3
# 4083                   3
# 20322                  5
# 5671                   3
# 43805                  1
# 47318                  1

# %%
data[['Sentiment','Sentiment_encoded']].value_counts()
# Out:
# Sentiment            Sentiment_encoded
# religion             5                    7998
# age                  0                    7992
# gender               2                    7973
# ethnicity            1                    7961
# not_cyberbullying    3                    7945
# other_cyberbullying  4                    7823
# dtype: int64

# %%
stop_words=set(stopwords.words('english'))

# %% [markdown]
# # Preprocessing of text in the data set

# %% [markdown]
# ### Function to remove emojis

# %%
def strip_emoji(text):
    return emoji.replace_emoji(text,replace='')

# %% [markdown]
# ## Function to convert text to lower case, remove(/r, /n character), URLs, non-utf characters, number, punctuation, stopwords

# %%
def strip_all_entities(text):
    text = text.replace('\r','').replace('\n',' ').lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub(r'[^\x00-\x7f]',r'', text)
    text = re.sub(r'(.)1+',r'1',text)
    text = re.sub('[0-9]+', '',text)
    stopchars = string.punctuation
    table = str.maketrans('', '',stopchars)
    text = text.translate(table)
    text = [word for word in text.split() if word not in stop_words]
    text = ' '.join(text)
    return text

# %% [markdown]
# ## Functions to remove contractions

# %%
def decontract(text):
    text = re.sub(r"can\'t"," cannot", text)
    text = re.sub(r"n\'t"," not", text)
    text = re.sub(r"\'re"," are", text)
    text = re.sub(r"\'s"," is", text)
    text = re.sub(r"\'d"," would", text)
    text = re.sub(r"\'ll"," will", text)
    text = re.sub(r"\'t"," not", text)
    text = re.sub(r"\'ve"," have", text)
    text = re.sub(r"\'m"," am", text)
    return text

# %% [markdown]
# ## Function to clean hashtags

# %%
def clean_hashtags(tweet):
    new_tweet = " ".join(word.strip() for word in re.split('#(?!(?:hastags)\b)[\w-]+(?=(?:\s+#[w-]+)*\s*$)', tweet))
    new_tweet2 = " ".join(word.strip() for word in re.split('#|_', new_tweet))
    return new_tweet2

# %% [markdown]
# ## Function to filter special character such as dollar and &

# %%
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if( '$' in word )  | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

# %% [markdown]
# ## Function to remove multiple sequence spaces

# %%
def remove_mult_spaces(text):
    return re.sub("\s\s+", " ", text)

# %% [markdown]
# ## Function to apply stemming to words

# %%
def stemmer(text):
    tokenized = nltk.word_tokenize(text)
    ps = PorterStemmer()
    return ' '.join([ps.stem(words) for words in tokenized])

# %% [markdown]
# ## Function to apply lemmatization to words

# %%
def lemmatize(text):
    tokenized = nltk.word_tokenize(text)
    lm = WordNetLemmatizer()
    return ' '.join([lm.lemmatize(words) for words in tokenized])

# %% [markdown]
# # A super function which will be used to preprocess text by applying all the above functions:

# %%
def preprocess(text):
    text = strip_emoji(text)
    text = decontract(text)
    text = strip_all_entities(text)
    text = clean_hashtags(text)
    text = filter_chars(text)
    text = remove_mult_spaces(text)
    text = stemmer(text)
    text = lemmatize(text)
    return text

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
data['Cleaned_Text'] = data['Text'].apply(preprocess)

# %%
data.sample(10)
# Out:
#                                                     Text          Sentiment  \
# 3960   Secret's Anti-Bullying Campaign Appears to Get...  not_cyberbullying
# 1016   I really can't stand corp I.T in PDX missing t...  not_cyberbullying
# 17939  Because of some idiots, you blaming entire com...           religion
# 17329  Islamic terrorism is spreading all over the wo...           religion
# 22934  RT @4chunat1: CNN reports on the murders of ho...           religion
# 18764  Absolutely wrong, you will believe anything, l...           religion
# 37011  All these people who refuse to let him answer ...                age
# 20334  Um...that's total BS. The fact is that America...           religion
# 36238  it’s been a long day for Bible verse in the bi...                age
# 13793  @IanOKParty that last tweet proves I am the on...             gender
#
#        Sentiment_encoded                                       Cleaned_Text
# 3960                   3  secret antibulli campaign appear get facebook ...
# 1016                   3  realli can not stand corp pdx miss bay old sch...
# 17939                  5  idiot blame entir commun like blame entir musl...
# 17329                  5  islam terror spread world corona viru u nkli m...
# 22934                  5  rt cnn report murder homosexu islam state prob...
# 18764                  5  absolut wrong believ anyth like payout porn st...
# 37011                  0  peopl refus let answer bulli know bulli exist ...
# 20334                  5  umthat total b fact american christian radic a...
# 36238                  0  long day bibl vers bio bulli kid high school g...
# 13793                  2       last tweet prove one gay rape nerd joke town

# %% [markdown]
# ## Cleaned text from the tweets have been added in the data frame

# %% [markdown]
# ## Dealing with duplicate text in the data frame

# %%
data['Text'].duplicated().sum()
# Out:
# 1675

# %%
data['Cleaned_Text'].duplicated().sum()
# Out:
# 3041

# %%
data.drop_duplicates('Cleaned_Text',inplace = True)

# %%
data['Sentiment'].value_counts()
# Out:
# religion               7952
# age                    7884
# ethnicity              7770
# not_cyberbullying      7646
# gender                 7620
# other_cyberbullying    5779
# Name: Sentiment, dtype: int64

# %% [markdown]
# ## Tokenization of words

# %%
data['words_list'] = data['Cleaned_Text'].apply(word_tokenize)
data
# Out:
#                                                     Text          Sentiment  \
# 0      In other words #katandandre, your food was cra...  not_cyberbullying
# 1      Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2      @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3      @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4      @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# ...                                                  ...                ...
# 47687  Black ppl aren't expected to do anything, depe...          ethnicity
# 47688  Turner did not withhold his disappointment. Tu...          ethnicity
# 47689  I swear to God. This dumb nigger bitch. I have...          ethnicity
# 47690  Yea fuck you RT @therealexel: IF YOURE A NIGGE...          ethnicity
# 47691  Bro. U gotta chill RT @CHILLShrammy: Dog FUCK ...          ethnicity
#
#        Sentiment_encoded                                       Cleaned_Text  \
# 0                      3                 word katandandr food crapilici mkr
# 1                      3  aussietv white mkr theblock imacelebrityau tod...
# 2                      3                     classi whore red velvet cupcak
# 3                      3  meh p thank head concern anoth angri dude twitter
# 4                      3  isi account pretend kurdish account like islam...
# ...                  ...                                                ...
# 47687                  1  black ppl expect anyth depend anyth yet free p...
# 47688                  1  turner withhold disappoint turner call court a...
# 47689                  1  swear god dumb nigger bitch got bleach hair re...
# 47690                  1  yea fuck rt your nigger fuck unfollow fuck dum...
# 47691                  1  bro u got ta chill rt dog fuck kp dumb nigger ...
#
#                                               words_list
# 0               [word, katandandr, food, crapilici, mkr]
# 1      [aussietv, white, mkr, theblock, imacelebritya...
# 2                   [classi, whore, red, velvet, cupcak]
# 3      [meh, p, thank, head, concern, anoth, angri, d...
# 4      [isi, account, pretend, kurdish, account, like...
# ...                                                  ...
# 47687  [black, ppl, expect, anyth, depend, anyth, yet...
# 47688  [turner, withhold, disappoint, turner, call, c...
# 47689  [swear, god, dumb, nigger, bitch, got, bleach,...
# 47690  [yea, fuck, rt, your, nigger, fuck, unfollow, ...
# 47691  [bro, u, got, ta, chill, rt, dog, fuck, kp, du...
#
# [44651 rows x 5 columns]

# %% [markdown]
# # VISUALIZATION OF THE DATA

# %%
length = []
for text in data.words_list:
    tweet_len = len(text)
    length.append(tweet_len)
data['length'] = length

# %%
def plot_wordcloud(cyberbullying_type):
    string = ""
    for i in data[data.Sentiment == cyberbullying_type].Cleaned_Text.values:
        string = string + " " + i.strip()
    custom_mask = np.array(Image.open('/content/Logo_of_Twitter.png'))
    #mask_colors = ImageColorGenerator(custom_mask)
    mask_colors = ImageColorGenerator(custom_mask)


    wordcloud = WordCloud(background_color='white',max_words=200, max_font_size=256,
        random_state=42, width=custom_mask.shape[1],height=custom_mask.shape[0],mask = custom_mask,min_font_size = 10,color_func=mask_colors).generate(string)

    # plot the WordCloud image
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
    plt.title(cyberbullying_type)
    plt.show()
    del string

# %%
data.shape
# Out:
# (44651, 6)

# %%
data['length'].describe()
# Out:
# count    44651.000000
# mean        13.376251
# std          8.373548
# min          0.000000
# 25%          7.000000
# 50%         12.000000
# 75%         19.000000
# max        384.000000
# Name: length, dtype: float64

# %%
plt.figure(figsize=(20,12))
sns.boxplot(x='length', data=data, color='red')
# Out:
# <Axes: xlabel='length'>

# %%
plt.figure(figsize=(20,12))
ax = sns.countplot(x='length', data=data, palette='rocket_r')

# %% [markdown]
# ## Splitting data based on sentiment for data exploration

# %%
notcyber_bullying_type = data[data['Sentiment']=='not_cyberbullying']
gender_type = data[data['Sentiment']=='gender']
religion_type = data[data['Sentiment']=='religion']
other_cyberbullying_type = data[data['Sentiment']=='other_cyberbullying']
age_type = data[data['Sentiment']=='age']
ethnicity_type = data[data['Sentiment']=='ethnicity']

# %% [markdown]
# ## GENDER BASED CYBER BULLYING

# %%
gender = Counter([item for sublist in gender_type['words_list'] for item in sublist])
top20_gender = pd.DataFrame(gender.most_common(20))
top20_gender.columns = ['Top Words','Count']
top20_gender.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_8e8b8_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8e8b8_row1_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_8e8b8_row2_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_8e8b8_row3_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_8e8b8_row4_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_8e8b8_row5_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_8e8b8_row6_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_8e8b8_row7_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8e8b8_row8_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_8e8b8_row9_col1, #T_8e8b8_row10_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_8e8b8_row11_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_8e8b8_row12_col1, #T_8e8b8_row13_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8e8b8_row14_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_8e8b8_row15_col1, #T_8e8b8_row16_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8e8b8_row17_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_8e8b8_row18_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8e8b8_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8e8b8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e8b8_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_8e8b8_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e8b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e8b8_row0_col0" class="data row0 col0" >joke</td>
#       <td id="T_8e8b8_row0_col1" class="data row0 col1" >5179</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e8b8_row1_col0" class="data row1 col0" >rape</td>
#       <td id="T_8e8b8_row1_col1" class="data row1 col1" >4070</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e8b8_row2_col0" class="data row2 col0" >gay</td>
#       <td id="T_8e8b8_row2_col1" class="data row2 col1" >3852</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e8b8_row3_col0" class="data row3 col0" >call</td>
#       <td id="T_8e8b8_row3_col1" class="data row3 col1" >1401</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e8b8_row4_col0" class="data row4 col0" >make</td>
#       <td id="T_8e8b8_row4_col1" class="data row4 col1" >1283</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8e8b8_row5_col0" class="data row5 col0" >rt</td>
#       <td id="T_8e8b8_row5_col1" class="data row5 col1" >1221</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8e8b8_row6_col0" class="data row6 col0" >woman</td>
#       <td id="T_8e8b8_row6_col1" class="data row6 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8e8b8_row7_col0" class="data row7 col0" >bitch</td>
#       <td id="T_8e8b8_row7_col1" class="data row7 col1" >1146</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8e8b8_row8_col0" class="data row8 col0" >femal</td>
#       <td id="T_8e8b8_row8_col1" class="data row8 col1" >1108</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8e8b8_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_8e8b8_row9_col1" class="data row9 col1" >988</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8e8b8_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_8e8b8_row10_col1" class="data row10 col1" >978</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8e8b8_row11_col0" class="data row11 col0" >sexist</td>
#       <td id="T_8e8b8_row11_col1" class="data row11 col1" >953</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8e8b8_row12_col0" class="data row12 col0" >funni</td>
#       <td id="T_8e8b8_row12_col1" class="data row12 col1" >662</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8e8b8_row13_col0" class="data row13 col0" >mkr</td>
#       <td id="T_8e8b8_row13_col1" class="data row13 col1" >659</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8e8b8_row14_col0" class="data row14 col0" >men</td>
#       <td id="T_8e8b8_row14_col1" class="data row14 col1" >614</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8e8b8_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_8e8b8_row15_col1" class="data row15 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8e8b8_row16_col0" class="data row16 col0" >think</td>
#       <td id="T_8e8b8_row16_col1" class="data row16 col1" >592</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8e8b8_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_8e8b8_row17_col1" class="data row17 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8e8b8_row18_col0" class="data row18 col0" >fuck</td>
#       <td id="T_8e8b8_row18_col1" class="data row18 col1" >548</td>
#     </tr>
#     <tr>
#       <th id="T_8e8b8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8e8b8_row19_col0" class="data row19 col0" >use</td>
#       <td id="T_8e8b8_row19_col1" class="data row19 col1" >441</td>
#     </tr>
#   </tbody>
# </table>

# %%
ig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_gender, y="Count", x="Top Words")
plt.title("Top 20 words in Gender Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Gender Cyberbullying')

# %%
plot_wordcloud('gender')

# %% [markdown]
# ## RELIGION BASED CYBERBULLYING

# %%
religion = Counter([item for sublist in religion_type['words_list'] for item in sublist])
top20_religion = pd.DataFrame(religion.most_common(20))
top20_religion.columns = ['Top Words','Count']
top20_religion.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_1b6a9_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1b6a9_row1_col1 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_1b6a9_row2_col1 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_1b6a9_row3_col1 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_1b6a9_row4_col1 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_1b6a9_row5_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_1b6a9_row6_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_1b6a9_row7_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_1b6a9_row8_col1, #T_1b6a9_row9_col1 {
#   background-color: #fedaca;
#   color: #000000;
# }
# #T_1b6a9_row10_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_1b6a9_row11_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_1b6a9_row12_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_1b6a9_row13_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_1b6a9_row14_col1, #T_1b6a9_row15_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_1b6a9_row16_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_1b6a9_row17_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_1b6a9_row18_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_1b6a9_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_1b6a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b6a9_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_1b6a9_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b6a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b6a9_row0_col0" class="data row0 col0" >muslim</td>
#       <td id="T_1b6a9_row0_col1" class="data row0 col1" >4618</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b6a9_row1_col0" class="data row1 col0" >idiot</td>
#       <td id="T_1b6a9_row1_col1" class="data row1 col1" >3075</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b6a9_row2_col0" class="data row2 col0" >islam</td>
#       <td id="T_1b6a9_row2_col1" class="data row2 col1" >2440</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b6a9_row3_col0" class="data row3 col0" >christian</td>
#       <td id="T_1b6a9_row3_col1" class="data row3 col1" >2132</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b6a9_row4_col0" class="data row4 col0" >u</td>
#       <td id="T_1b6a9_row4_col1" class="data row4 col1" >1922</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b6a9_row5_col0" class="data row5 col0" >terrorist</td>
#       <td id="T_1b6a9_row5_col1" class="data row5 col1" >1378</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b6a9_row6_col0" class="data row6 col0" >right</td>
#       <td id="T_1b6a9_row6_col1" class="data row6 col1" >1289</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b6a9_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_1b6a9_row7_col1" class="data row7 col1" >1276</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b6a9_row8_col0" class="data row8 col0" >support</td>
#       <td id="T_1b6a9_row8_col1" class="data row8 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1b6a9_row9_col0" class="data row9 col0" >woman</td>
#       <td id="T_1b6a9_row9_col1" class="data row9 col1" >1247</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1b6a9_row10_col0" class="data row10 col0" >terror</td>
#       <td id="T_1b6a9_row10_col1" class="data row10 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1b6a9_row11_col0" class="data row11 col0" >radic</td>
#       <td id="T_1b6a9_row11_col1" class="data row11 col1" >1110</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1b6a9_row12_col0" class="data row12 col0" >peopl</td>
#       <td id="T_1b6a9_row12_col1" class="data row12 col1" >1076</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1b6a9_row13_col0" class="data row13 col0" >say</td>
#       <td id="T_1b6a9_row13_col1" class="data row13 col1" >812</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1b6a9_row14_col0" class="data row14 col0" >amp</td>
#       <td id="T_1b6a9_row14_col1" class="data row14 col1" >769</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1b6a9_row15_col0" class="data row15 col0" >know</td>
#       <td id="T_1b6a9_row15_col1" class="data row15 col1" >759</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1b6a9_row16_col0" class="data row16 col0" >human</td>
#       <td id="T_1b6a9_row16_col1" class="data row16 col1" >744</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1b6a9_row17_col0" class="data row17 col0" >kill</td>
#       <td id="T_1b6a9_row17_col1" class="data row17 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1b6a9_row18_col0" class="data row18 col0" >hindu</td>
#       <td id="T_1b6a9_row18_col1" class="data row18 col1" >688</td>
#     </tr>
#     <tr>
#       <th id="T_1b6a9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1b6a9_row19_col0" class="data row19 col0" >one</td>
#       <td id="T_1b6a9_row19_col1" class="data row19 col1" >666</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_religion, y="Count", x="Top Words")
plt.title("Top 20 words in Religion Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Religion Cyberbullying')

# %%
plot_wordcloud('religion')

# %% [markdown]
# ## AGE BASED CYBER BULLYING

# %%
age = Counter([item for sublist in age_type['words_list'] for item in sublist])
top20_age = pd.DataFrame(age.most_common(20))
top20_age.columns = ['Top Words','Count']
top20_age.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_7a90d_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7a90d_row1_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_7a90d_row2_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_7a90d_row3_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_7a90d_row4_col1 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_7a90d_row5_col1, #T_7a90d_row6_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_7a90d_row7_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_7a90d_row8_col1, #T_7a90d_row9_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_7a90d_row10_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_7a90d_row11_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_7a90d_row12_col1, #T_7a90d_row13_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_7a90d_row14_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_7a90d_row15_col1, #T_7a90d_row16_col1, #T_7a90d_row17_col1, #T_7a90d_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_7a90d_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7a90d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a90d_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_7a90d_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a90d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a90d_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_7a90d_row0_col1" class="data row0 col1" >8899</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a90d_row1_col0" class="data row1 col0" >school</td>
#       <td id="T_7a90d_row1_col1" class="data row1 col1" >8426</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a90d_row2_col0" class="data row2 col0" >high</td>
#       <td id="T_7a90d_row2_col1" class="data row2 col1" >4861</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a90d_row3_col0" class="data row3 col0" >girl</td>
#       <td id="T_7a90d_row3_col1" class="data row3 col1" >4616</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a90d_row4_col0" class="data row4 col0" >like</td>
#       <td id="T_7a90d_row4_col1" class="data row4 col1" >2076</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a90d_row5_col0" class="data row5 col0" >get</td>
#       <td id="T_7a90d_row5_col1" class="data row5 col1" >1051</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a90d_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_7a90d_row6_col1" class="data row6 col1" >1044</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a90d_row7_col0" class="data row7 col0" >peopl</td>
#       <td id="T_7a90d_row7_col1" class="data row7 col1" >934</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a90d_row8_col0" class="data row8 col0" >got</td>
#       <td id="T_7a90d_row8_col1" class="data row8 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a90d_row9_col0" class="data row9 col0" >kid</td>
#       <td id="T_7a90d_row9_col1" class="data row9 col1" >809</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a90d_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_7a90d_row10_col1" class="data row10 col1" >762</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a90d_row11_col0" class="data row11 col0" >middl</td>
#       <td id="T_7a90d_row11_col1" class="data row11 col1" >714</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7a90d_row12_col0" class="data row12 col0" >friend</td>
#       <td id="T_7a90d_row12_col1" class="data row12 col1" >632</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7a90d_row13_col0" class="data row13 col0" >im</td>
#       <td id="T_7a90d_row13_col1" class="data row13 col1" >625</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7a90d_row14_col0" class="data row14 col0" >year</td>
#       <td id="T_7a90d_row14_col1" class="data row14 col1" >586</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7a90d_row15_col0" class="data row15 col0" >go</td>
#       <td id="T_7a90d_row15_col1" class="data row15 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7a90d_row16_col0" class="data row16 col0" >look</td>
#       <td id="T_7a90d_row16_col1" class="data row16 col1" >545</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7a90d_row17_col0" class="data row17 col0" >amp</td>
#       <td id="T_7a90d_row17_col1" class="data row17 col1" >527</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7a90d_row18_col0" class="data row18 col0" >know</td>
#       <td id="T_7a90d_row18_col1" class="data row18 col1" >511</td>
#     </tr>
#     <tr>
#       <th id="T_7a90d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7a90d_row19_col0" class="data row19 col0" >u</td>
#       <td id="T_7a90d_row19_col1" class="data row19 col1" >477</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_age, y="Count", x="Top Words")
plt.title("Top 20 words in Age Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Age Cyberbullying')

# %%
plot_wordcloud('age')

# %% [markdown]
# ## ETHNICITY BASED CYBERBULLYING

# %%
ethnicity = Counter([item for sublist in ethnicity_type['words_list'] for item in sublist])
top20_ethnicity = pd.DataFrame(ethnicity.most_common(20))
top20_ethnicity.columns = ['Top Words','Count']
top20_ethnicity.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_0908e_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0908e_row1_col1 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_0908e_row2_col1 {
#   background-color: #b21218;
#   color: #f1f1f1;
# }
# #T_0908e_row3_col1 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_0908e_row4_col1 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_0908e_row5_col1 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_0908e_row6_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_0908e_row7_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_0908e_row8_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_0908e_row9_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_0908e_row10_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_0908e_row11_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_0908e_row12_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_0908e_row13_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_0908e_row14_col1 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_0908e_row15_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_0908e_row16_col1, #T_0908e_row17_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_0908e_row18_col1, #T_0908e_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0908e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0908e_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_0908e_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0908e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0908e_row0_col0" class="data row0 col0" >fuck</td>
#       <td id="T_0908e_row0_col1" class="data row0 col1" >5892</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0908e_row1_col0" class="data row1 col0" >nigger</td>
#       <td id="T_0908e_row1_col1" class="data row1 col1" >5456</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0908e_row2_col0" class="data row2 col0" >dumb</td>
#       <td id="T_0908e_row2_col1" class="data row2 col1" >5003</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0908e_row3_col0" class="data row3 col0" >as</td>
#       <td id="T_0908e_row3_col1" class="data row3 col1" >2241</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0908e_row4_col0" class="data row4 col0" >black</td>
#       <td id="T_0908e_row4_col1" class="data row4 col1" >2134</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0908e_row5_col0" class="data row5 col0" >u</td>
#       <td id="T_0908e_row5_col1" class="data row5 col1" >2107</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0908e_row6_col0" class="data row6 col0" >white</td>
#       <td id="T_0908e_row6_col1" class="data row6 col1" >1557</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0908e_row7_col0" class="data row7 col0" >call</td>
#       <td id="T_0908e_row7_col1" class="data row7 col1" >1381</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0908e_row8_col0" class="data row8 col0" >peopl</td>
#       <td id="T_0908e_row8_col1" class="data row8 col1" >1182</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0908e_row9_col0" class="data row9 col0" >rt</td>
#       <td id="T_0908e_row9_col1" class="data row9 col1" >1166</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0908e_row10_col0" class="data row10 col0" >obama</td>
#       <td id="T_0908e_row10_col1" class="data row10 col1" >1112</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0908e_row11_col0" class="data row11 col0" >one</td>
#       <td id="T_0908e_row11_col1" class="data row11 col1" >1058</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0908e_row12_col0" class="data row12 col0" >like</td>
#       <td id="T_0908e_row12_col1" class="data row12 col1" >1035</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0908e_row13_col0" class="data row13 col0" >bitch</td>
#       <td id="T_0908e_row13_col1" class="data row13 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0908e_row14_col0" class="data row14 col0" >ur</td>
#       <td id="T_0908e_row14_col1" class="data row14 col1" >987</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0908e_row15_col0" class="data row15 col0" >say</td>
#       <td id="T_0908e_row15_col1" class="data row15 col1" >817</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0908e_row16_col0" class="data row16 col0" >first</td>
#       <td id="T_0908e_row16_col1" class="data row16 col1" >745</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0908e_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_0908e_row17_col1" class="data row17 col1" >740</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0908e_row18_col0" class="data row18 col0" >anyth</td>
#       <td id="T_0908e_row18_col1" class="data row18 col1" >708</td>
#     </tr>
#     <tr>
#       <th id="T_0908e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0908e_row19_col0" class="data row19 col0" >racism</td>
#       <td id="T_0908e_row19_col1" class="data row19 col1" >689</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_ethnicity, y="Count", x="Top Words")
plt.title("Top 20 words in Ethnicity Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Ethnicity Cyberbullying')

# %%
plot_wordcloud('ethnicity')

# %% [markdown]
# ##  OTHER TYPES OF CYBERBULLYING

# %%
other_cyberbullying = Counter([item for sublist in other_cyberbullying_type['words_list'] for item in sublist])
top20_other_cyberbullying = pd.DataFrame(other_cyberbullying.most_common(20))
top20_other_cyberbullying.columns = ['Top Words','Count']
top20_other_cyberbullying.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_18c79_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_18c79_row1_col1 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_18c79_row2_col1 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_18c79_row3_col1 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_18c79_row4_col1 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_18c79_row5_col1 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_18c79_row6_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_18c79_row7_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_18c79_row8_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_18c79_row9_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_18c79_row10_col1 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_18c79_row11_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_18c79_row12_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_18c79_row13_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_18c79_row14_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_18c79_row15_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_18c79_row16_col1, #T_18c79_row17_col1, #T_18c79_row18_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_18c79_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_18c79" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18c79_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_18c79_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18c79_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18c79_row0_col0" class="data row0 col0" >bulli</td>
#       <td id="T_18c79_row0_col1" class="data row0 col1" >882</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18c79_row1_col0" class="data row1 col0" >rt</td>
#       <td id="T_18c79_row1_col1" class="data row1 col1" >727</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18c79_row2_col0" class="data row2 col0" >fuck</td>
#       <td id="T_18c79_row2_col1" class="data row2 col1" >509</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18c79_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_18c79_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18c79_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_18c79_row4_col1" class="data row4 col1" >393</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18c79_row5_col0" class="data row5 col0" >peopl</td>
#       <td id="T_18c79_row5_col1" class="data row5 col1" >353</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18c79_row6_col0" class="data row6 col0" >go</td>
#       <td id="T_18c79_row6_col1" class="data row6 col1" >277</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18c79_row7_col0" class="data row7 col0" >idiot</td>
#       <td id="T_18c79_row7_col1" class="data row7 col1" >261</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18c79_row8_col0" class="data row8 col0" >know</td>
#       <td id="T_18c79_row8_col1" class="data row8 col1" >241</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18c79_row9_col0" class="data row9 col0" >think</td>
#       <td id="T_18c79_row9_col1" class="data row9 col1" >237</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_18c79_row10_col0" class="data row10 col0" >would</td>
#       <td id="T_18c79_row10_col1" class="data row10 col1" >235</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_18c79_row11_col0" class="data row11 col0" >u</td>
#       <td id="T_18c79_row11_col1" class="data row11 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_18c79_row12_col0" class="data row12 col0" >make</td>
#       <td id="T_18c79_row12_col1" class="data row12 col1" >215</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_18c79_row13_col0" class="data row13 col0" >one</td>
#       <td id="T_18c79_row13_col1" class="data row13 col1" >205</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_18c79_row14_col0" class="data row14 col0" >time</td>
#       <td id="T_18c79_row14_col1" class="data row14 col1" >202</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_18c79_row15_col0" class="data row15 col0" >hate</td>
#       <td id="T_18c79_row15_col1" class="data row15 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_18c79_row16_col0" class="data row16 col0" >want</td>
#       <td id="T_18c79_row16_col1" class="data row16 col1" >183</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_18c79_row17_col0" class="data row17 col0" >thing</td>
#       <td id="T_18c79_row17_col1" class="data row17 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_18c79_row18_col0" class="data row18 col0" >need</td>
#       <td id="T_18c79_row18_col1" class="data row18 col1" >182</td>
#     </tr>
#     <tr>
#       <th id="T_18c79_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_18c79_row19_col0" class="data row19 col0" >see</td>
#       <td id="T_18c79_row19_col1" class="data row19 col1" >178</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_other_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Other Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Other Cyberbullying')

# %%
plot_wordcloud('other_cyberbullying')

# %% [markdown]
# ## TWEET WITHOUT CYBERBULLYING

# %%
not_cyberbullying = Counter([item for sublist in notcyber_bullying_type['words_list'] for item in sublist])
top20_not_cyberbullying = pd.DataFrame(not_cyberbullying.most_common(20))
top20_not_cyberbullying.columns = ['Top Words','Count']
top20_not_cyberbullying.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_1723c_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1723c_row1_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_1723c_row2_col1 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_1723c_row3_col1, #T_1723c_row4_col1 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_1723c_row5_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_1723c_row6_col1 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_1723c_row7_col1, #T_1723c_row8_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_1723c_row9_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_1723c_row10_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_1723c_row11_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_1723c_row12_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_1723c_row13_col1, #T_1723c_row14_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_1723c_row15_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_1723c_row16_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_1723c_row17_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_1723c_row18_col1, #T_1723c_row19_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_1723c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1723c_level0_col0" class="col_heading level0 col0" >Top Words</th>
#       <th id="T_1723c_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1723c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1723c_row0_col0" class="data row0 col0" >mkr</td>
#       <td id="T_1723c_row0_col1" class="data row0 col1" >1674</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1723c_row1_col0" class="data row1 col0" >bulli</td>
#       <td id="T_1723c_row1_col1" class="data row1 col1" >1102</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1723c_row2_col0" class="data row2 col0" >rt</td>
#       <td id="T_1723c_row2_col1" class="data row2 col1" >785</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1723c_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_1723c_row3_col1" class="data row3 col1" >424</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1723c_row4_col0" class="data row4 col0" >get</td>
#       <td id="T_1723c_row4_col1" class="data row4 col1" >423</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1723c_row5_col0" class="data row5 col0" >go</td>
#       <td id="T_1723c_row5_col1" class="data row5 col1" >394</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1723c_row6_col0" class="data row6 col0" >school</td>
#       <td id="T_1723c_row6_col1" class="data row6 col1" >374</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1723c_row7_col0" class="data row7 col0" >kat</td>
#       <td id="T_1723c_row7_col1" class="data row7 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1723c_row8_col0" class="data row8 col0" >would</td>
#       <td id="T_1723c_row8_col1" class="data row8 col1" >286</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1723c_row9_col0" class="data row9 col0" >peopl</td>
#       <td id="T_1723c_row9_col1" class="data row9 col1" >272</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1723c_row10_col0" class="data row10 col0" >one</td>
#       <td id="T_1723c_row10_col1" class="data row10 col1" >264</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1723c_row11_col0" class="data row11 col0" >amp</td>
#       <td id="T_1723c_row11_col1" class="data row11 col1" >258</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1723c_row12_col0" class="data row12 col0" >think</td>
#       <td id="T_1723c_row12_col1" class="data row12 col1" >242</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1723c_row13_col0" class="data row13 col0" >u</td>
#       <td id="T_1723c_row13_col1" class="data row13 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1723c_row14_col0" class="data row14 col0" >know</td>
#       <td id="T_1723c_row14_col1" class="data row14 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1723c_row15_col0" class="data row15 col0" >time</td>
#       <td id="T_1723c_row15_col1" class="data row15 col1" >224</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1723c_row16_col0" class="data row16 col0" >make</td>
#       <td id="T_1723c_row16_col1" class="data row16 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1723c_row17_col0" class="data row17 col0" >love</td>
#       <td id="T_1723c_row17_col1" class="data row17 col1" >207</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1723c_row18_col0" class="data row18 col0" >andr</td>
#       <td id="T_1723c_row18_col1" class="data row18 col1" >194</td>
#     </tr>
#     <tr>
#       <th id="T_1723c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1723c_row19_col0" class="data row19 col0" >need</td>
#       <td id="T_1723c_row19_col1" class="data row19 col1" >191</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = plt.figure(figsize=(15,8))
sns.barplot(data=top20_not_cyberbullying, y="Count", x="Top Words")
plt.title("Top 20 words in Not Cyberbullying")
# Out:
# Text(0.5, 1.0, 'Top 20 words in Not Cyberbullying')

# %%
plot_wordcloud('not_cyberbullying')

# %%
data.head(10)
# Out:
#                                                 Text          Sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
# 5  @Raja5aab @Quickieleaks Yes, the test of god i...  not_cyberbullying
# 6  Itu sekolah ya bukan tempat bully! Ga jauh kay...  not_cyberbullying
# 7  Karma. I hope it bites Kat on the butt. She is...  not_cyberbullying
# 8       @stockputout everything but mostly my priest  not_cyberbullying
# 9  Rebecca Black Drops Out of School Due to Bully...  not_cyberbullying
#
#    Sentiment_encoded                                       Cleaned_Text  \
# 0                  3                 word katandandr food crapilici mkr
# 1                  3  aussietv white mkr theblock imacelebrityau tod...
# 2                  3                     classi whore red velvet cupcak
# 3                  3  meh p thank head concern anoth angri dude twitter
# 4                  3  isi account pretend kurdish account like islam...
# 5                  3  ye test god good bad indiffer weird whatev pro...
# 6                  3  itu sekolah ya bukan tempat bulli ga jauh kaya...
# 7                  3                 karma hope bite kat butt nasti mkr
# 8                  3                              everyth mostli priest
# 9                  3                rebecca black drop school due bulli
#
#                                           words_list  length
# 0           [word, katandandr, food, crapilici, mkr]       5
# 1  [aussietv, white, mkr, theblock, imacelebritya...      11
# 2               [classi, whore, red, velvet, cupcak]       5
# 3  [meh, p, thank, head, concern, anoth, angri, d...       9
# 4  [isi, account, pretend, kurdish, account, like...       8
# 5  [ye, test, god, good, bad, indiffer, weird, wh...      11
# 6  [itu, sekolah, ya, bukan, tempat, bulli, ga, j...      10
# 7         [karma, hope, bite, kat, butt, nasti, mkr]       7
# 8                          [everyth, mostli, priest]       3
# 9         [rebecca, black, drop, school, due, bulli]       6

# %%
data.Sentiment.value_counts()
# Out:
# religion               7952
# age                    7884
# ethnicity              7770
# not_cyberbullying      7646
# gender                 7620
# other_cyberbullying    5779
# Name: Sentiment, dtype: int64

# %%
sentiments = ['religion','age','ethnicity','gender','not_cyberbullying','other_cyberbullying']

# %%
data.head()
# Out:
#                                                 Text          Sentiment  \
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying
#
#    Sentiment_encoded                                       Cleaned_Text  \
# 0                  3                 word katandandr food crapilici mkr
# 1                  3  aussietv white mkr theblock imacelebrityau tod...
# 2                  3                     classi whore red velvet cupcak
# 3                  3  meh p thank head concern anoth angri dude twitter
# 4                  3  isi account pretend kurdish account like islam...
#
#                                           words_list  length
# 0           [word, katandandr, food, crapilici, mkr]       5
# 1  [aussietv, white, mkr, theblock, imacelebritya...      11
# 2               [classi, whore, red, velvet, cupcak]       5
# 3  [meh, p, thank, head, concern, anoth, angri, d...       9
# 4  [isi, account, pretend, kurdish, account, like...       8

# %%
data.columns
# Out:
# Index(['Text', 'Sentiment', 'Sentiment_encoded', 'Cleaned_Text', 'words_list',
#        'length'],
#       dtype='object')

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# # Splitting the data into train and test sets

# %%
X, Y = data['Cleaned_Text'], data['Sentiment_encoded']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, stratify=Y, random_state= 25)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (35720,) (8931,) (35720,) (8931,)

# %% [markdown]
# ## tf-idf vectorization

# %%
tf_idf = TfidfVectorizer()
X_train_tf = tf_idf.fit_transform(X_train)
X_test_tf = tf_idf.transform(X_test)
print(X_train_tf.shape)
print(X_test_tf.shape)
# Out:
# (35720, 31895)
# (8931, 31895)

# %%
X_train_tf
# Out:
# <35720x31895 sparse matrix of type '<class 'numpy.float64'>'
# 	with 440320 stored elements in Compressed Sparse Row format>

# %%
X_test_tf
# Out:
# <8931x31895 sparse matrix of type '<class 'numpy.float64'>'
# 	with 105165 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Trying different ML models

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train_tf, Y_train)
# Out:
# LogisticRegression()

# %%
log_cv_score = cross_val_score(log_reg, X_train_tf, Y_train, cv=5, scoring= 'f1_macro', n_jobs=-1)

# %%
mean_log_cv = np.mean(log_cv_score)
mean_log_cv
# Out:
# 0.8251150954823713

# %%
ypred = log_reg.predict(X_test_tf)
print(log_reg.score(X_test_tf, Y_test))
# Out:
# 0.841563094838204

# %% [markdown]
# ## Support Vector Classifier

# %%
lin_svc = LinearSVC()

# %%
lin_svc_cv_score = cross_val_score(lin_svc,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_lin_svc_cv = np.mean(lin_svc_cv_score)
mean_lin_svc_cv
# Out:
# 0.8227953965536946

# %% [markdown]
# ## Naive Bayes Classifier

# %%
multiNB = MultinomialNB()

# %%
multiNB_cv_score = cross_val_score(multiNB,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_multiNB_cv = np.mean(multiNB_cv_score)
mean_multiNB_cv
# Out:
# 0.6741382100970938

# %% [markdown]
# ## Decison Tree Classifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree_cv_score = cross_val_score(dtree,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_dtree_cv = np.mean(dtree_cv_score)
mean_dtree_cv
# Out:
# 0.8088877926004805

# %% [markdown]
# ## RandomForest Classifier

# %%
rand_forest = RandomForestClassifier()

# %%
rand_forest_cv_score = cross_val_score(rand_forest,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_rand_forest_cv = np.mean(rand_forest_cv_score)
mean_rand_forest_cv
# Out:
# 0.831975311829811

# %% [markdown]
# ## Adaboost Classifier

# %%
adab = AdaBoostClassifier()

# %%
adab_cv_score = cross_val_score(adab,X_train_tf,Y_train,cv=5,scoring='f1_macro',n_jobs=-1)
mean_adab_cv = np.mean(adab_cv_score)
mean_adab_cv
# Out:
# 0.7557848526233734

# %% [markdown]
# ## By trying different models we can see logistic regression, svm and random forest
# ## classifier performed similarly, so among these we will go with svm model as it is
# ## more generalised and light
# ## Fine Tuning Support Vector Classifier

# %%
svc1 = LinearSVC()
param_grid = {'C':[0.0001,0.001,0.01,0.1,1,10],
'loss':['hinge','squared_hinge'],
'fit_intercept':[True,False]}
grid_search = GridSearchCV(svc1,param_grid,cv=5,scoring='f1_macro',n_jobs=-1,verbose=0,return_train_score=True)
grid_search.fit(X_train_tf,Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearSVC(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10],
#                          'fit_intercept': [True, False],
#                          'loss': ['hinge', 'squared_hinge']},
#              return_train_score=True, scoring='f1_macro')

# %%
grid_search.best_estimator_
# Out:
# LinearSVC(C=1, loss='hinge')

# %%
grid_search.best_score_
# Out:
# 0.8271200193542588

# %% [markdown]
# # MODEL EVALUATION

# %%
lin_svc.fit(X_train_tf, Y_train)
y_pred = lin_svc.predict(X_test_tf)

# %%
def print_confusion_matrix(confusion_matrix, class_names, figsize= (10,7), fontsize = 14):
    df_cm = pd.DataFrame(confusion_matrix, index =class_names, columns = class_names)
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot = True, fmt = 'd')
    except ValueError:
        raise ValueError('Confusion matrix values must be integer.')
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('Truth')
    plt.xlabel('Preiction')

# %%
cm = confusion_matrix(Y_test, y_pred)
print_confusion_matrix(cm, sentiments)

# %%
print('Classification Report\n', classification_report(Y_test, y_pred, target_names=sentiments))
# Out:
# Classification Report
#                       precision    recall  f1-score   support
#
#            religion       0.92      0.97      0.95      1577
#                 age       0.96      0.98      0.97      1554
#           ethnicity       0.90      0.84      0.87      1524
#              gender       0.63      0.61      0.62      1529
#   not_cyberbullying       0.58      0.59      0.59      1156
# other_cyberbullying       0.95      0.96      0.95      1591
#
#            accuracy                           0.84      8931
#           macro avg       0.82      0.83      0.82      8931
#        weighted avg       0.84      0.84      0.84      8931

# %% [markdown]
# # Saving model

# %%
#pickle.dump(tf_idf, open('vectorizer.pkl', 'wb'))
#pickle.dump(lin_svc, open('model.pkl', 'wb'))
